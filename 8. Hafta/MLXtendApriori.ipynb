# %%
import numpy as np
import pandas as pd

# creating a matrix of ones and zeros
shein_matrix = np.random.binomial(size=(2000,25), n=1, p= 0.1)

#columns 
the_columns = ["Car & Slogan Graphic Drop Shoulder Tee",
              "Letter Graphic Drop Shoulder Longline Tee",
              "Drop Shoulder Letter & Eagle Print Tee",
              "Slogan Graphic Drop Shoulder Tee",
              "Mountain And Letter Graphic Tee",
              "Heart & Letter Graphic Tee",
              "DAZY Figure & Slogan Graphic Tee",
              "Letter & Rocket Print Tee",
              "Tie Dye Drop Shoulder Oversized Tee",
              "Letter Graphic Crew Neck Tee",
              "Figure Graphic Round Neck Tee",
              "Butterfly Print Round Neck Tee",
              "Letter and Car Print Top",
              "Planet Print Drop Shoulder Tee",
              "Heart And Wing Rhinestone Crop Top",
              "DAZY Letter Graphic Tee",
              "Two Tone Slogan Graphic Longline Tee",
              "Letter & Cup Print Tee",
              "Letter & Tape Print Tee","Honey Graphic Tie Dye Top",
              "Color Block Letter Graphic Tee",
              "Cartoon & Graphic Print Tee",
              "Rhinestone Letter Crop Tee",
              "California Graphic Short Sleeve Tee",
              "Moon & Mushroom Print Tee"]

#index
the_index = list(range(100001,102001))

#creating a dataframe 
shein_df = pd.DataFrame(shein_matrix, index=the_index, columns=the_columns)
shein_df.index.name = "Invoice No"
shein_df
# Out:
# C:\Users\Hp\anaconda33\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             Car & Slogan Graphic Drop Shoulder Tee  \
# Invoice No
# 100001                                           0
# 100002                                           0
# 100003                                           0
# 100004                                           0
# 100005                                           0
# ...                                            ...
# 101996                                           0
# 101997                                           0
# 101998                                           0
# 101999                                           0
# 102000                                           0
#
#             Letter Graphic Drop Shoulder Longline Tee  \
# Invoice No
# 100001                                              0
# 100002                                              0
# 100003                                              0
# 100004                                              0
# 100005                                              0
# ...                                               ...
# 101996                                              0
# 101997                                              0
# 101998                                              0
# 101999                                              0
# 102000                                              0
#
#             Drop Shoulder Letter & Eagle Print Tee  \
# Invoice No
# 100001                                           0
# 100002                                           1
# 100003                                           0
# 100004                                           0
# 100005                                           0
# ...                                            ...
# 101996                                           1
# 101997                                           0
# 101998                                           0
# 101999                                           0
# 102000                                           0
#
#             Slogan Graphic Drop Shoulder Tee  Mountain And Letter Graphic Tee  \
# Invoice No
# 100001                                     0                                0
# 100002                                     0                                1
# 100003                                     0                                1
# 100004                                     0                                0
# 100005                                     0                                0
# ...                                      ...                              ...
# 101996                                     0                                1
# 101997                                     0                                0
# 101998                                     0                                0
# 101999                                     0                                0
# 102000                                     0                                0
#
#             Heart & Letter Graphic Tee  DAZY Figure & Slogan Graphic Tee  \
# Invoice No
# 100001                               0                                 0
# 100002                               0                                 0
# 100003                               0                                 0
# 100004                               1                                 0
# 100005                               0                                 0
# ...                                ...                               ...
# 101996                               0                                 0
# 101997                               0                                 0
# 101998                               1                                 0
# 101999                               0                                 0
# 102000                               0                                 0
#
#             Letter & Rocket Print Tee  Tie Dye Drop Shoulder Oversized Tee  \
# Invoice No
# 100001                              0                                    0
# 100002                              0                                    0
# 100003                              0                                    0
# 100004                              0                                    0
# 100005                              0                                    0
# ...                               ...                                  ...
# 101996                              0                                    0
# 101997                              0                                    0
# 101998                              0                                    0
# 101999                              0                                    0
# 102000                              0                                    0
#
#             Letter Graphic Crew Neck Tee  ...  DAZY Letter Graphic Tee  \
# Invoice No                                ...
# 100001                                 0  ...                        0
# 100002                                 0  ...                        0
# 100003                                 0  ...                        0
# 100004                                 0  ...                        0
# 100005                                 0  ...                        0
# ...                                  ...  ...                      ...
# 101996                                 0  ...                        0
# 101997                                 0  ...                        0
# 101998                                 0  ...                        0
# 101999                                 0  ...                        0
# 102000                                 0  ...                        0
#
#             Two Tone Slogan Graphic Longline Tee  Letter & Cup Print Tee  \
# Invoice No
# 100001                                         0                       0
# 100002                                         0                       0
# 100003                                         0                       0
# 100004                                         0                       0
# 100005                                         1                       0
# ...                                          ...                     ...
# 101996                                         0                       0
# 101997                                         0                       0
# 101998                                         0                       0
# 101999                                         0                       0
# 102000                                         0                       0
#
#             Letter & Tape Print Tee  Honey Graphic Tie Dye Top  \
# Invoice No
# 100001                            0                          0
# 100002                            0                          0
# 100003                            0                          1
# 100004                            0                          0
# 100005                            0                          0
# ...                             ...                        ...
# 101996                            0                          0
# 101997                            0                          0
# 101998                            0                          0
# 101999                            0                          0
# 102000                            0                          0
#
#             Color Block Letter Graphic Tee  Cartoon & Graphic Print Tee  \
# Invoice No
# 100001                                   0                            1
# 100002                                   0                            1
# 100003                                   0                            0
# 100004                                   0                            0
# 100005                                   0                            0
# ...                                    ...                          ...
# 101996                                   1                            0
# 101997                                   0                            0
# 101998                                   0                            0
# 101999                                   1                            0
# 102000                                   0                            0
#
#             Rhinestone Letter Crop Tee  California Graphic Short Sleeve Tee  \
# Invoice No
# 100001                               0                                    0
# 100002                               0                                    0
# 100003                               0                                    0
# 100004                               1                                    0
# 100005                               1                                    0
# ...                                ...                                  ...
# 101996                               0                                    0
# 101997                               0                                    0
# 101998                               0                                    0
# 101999                               0                                    0
# 102000                               0                                    0
#
#             Moon & Mushroom Print Tee
# Invoice No
# 100001                              1
# 100002                              0
# 100003                              1
# 100004                              0
# 100005                              0
# ...                               ...
# 101996                              0
# 101997                              0
# 101998                              0
# 101999                              0
# 102000                              0
#
# [2000 rows x 25 columns]

# %%
#importing packages
from mlxtend.frequent_patterns import apriori

#getting frequent itemsets using support and ordering them from highest to lowest support
freq_items = apriori(shein_df, min_support = 0.01, max_len = 2, 
                     use_colnames=True).sort_values('support', 
                     ascending = False). reset_index(drop = True)
freq_items
# Out:
# C:\Users\Hp\anaconda33\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\Hp\anaconda33\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#      support                                           itemsets
# 0     0.1135                 (Slogan Graphic Drop Shoulder Tee)
# 1     0.1120                      (Cartoon & Graphic Print Tee)
# 2     0.1100                       (Heart & Letter Graphic Tee)
# 3     0.1100                 (DAZY Figure & Slogan Graphic Tee)
# 4     0.1090                           (Letter & Cup Print Tee)
# ..       ...                                                ...
# 174   0.0100  (California Graphic Short Sleeve Tee, Planet P...
# 175   0.0100  (Drop Shoulder Letter & Eagle Print Tee, Heart...
# 176   0.0100  (Cartoon & Graphic Print Tee, Tie Dye Drop Sho...
# 177   0.0100  (Figure Graphic Round Neck Tee, Tie Dye Drop S...
# 178   0.0100  (DAZY Figure & Slogan Graphic Tee, Butterfly P...
#
# [179 rows x 2 columns]

# %%
#importing packages
from mlxtend.frequent_patterns import association_rules

# computing all association rules and ordering them from highest to lowest lift value
the_rules = association_rules(freq_items, metric ='lift', min_threshold = 1).sort_values('lift', ascending = False). reset_index(drop = True)
the_rules
# Out:
# C:\Users\Hp\anaconda33\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                      antecedents  \
# 0             (Slogan Graphic Drop Shoulder Tee)
# 1          (California Graphic Short Sleeve Tee)
# 2    (Letter Graphic Drop Shoulder Longline Tee)
# 3                   (Heart & Letter Graphic Tee)
# 4               (Color Block Letter Graphic Tee)
# ..                                           ...
# 231                    (Letter & Tape Print Tee)
# 232           (Slogan Graphic Drop Shoulder Tee)
# 233                    (Letter & Tape Print Tee)
# 234       (Two Tone Slogan Graphic Longline Tee)
# 235                   (Letter and Car Print Top)
#
#                                      consequents  antecedent support  \
# 0          (California Graphic Short Sleeve Tee)              0.0930
# 1             (Slogan Graphic Drop Shoulder Tee)              0.0935
# 2                   (Heart & Letter Graphic Tee)              0.1005
# 3    (Letter Graphic Drop Shoulder Longline Tee)              0.0830
# 4               (Planet Print Drop Shoulder Tee)              0.1020
# ..                                           ...                 ...
# 231              (Figure Graphic Round Neck Tee)              0.1180
# 232                    (Letter & Tape Print Tee)              0.0930
# 233           (Slogan Graphic Drop Shoulder Tee)              0.1180
# 234                   (Letter and Car Print Top)              0.1135
# 235       (Two Tone Slogan Graphic Longline Tee)              0.0925
#
#      consequent support  support  confidence      lift  leverage  conviction
# 0                0.0935   0.0140    0.150538  1.610028  0.005305    1.067146
# 1                0.0930   0.0140    0.149733  1.610028  0.005305    1.066723
# 2                0.0830   0.0130    0.129353  1.558473  0.004658    1.053240
# 3                0.1005   0.0130    0.156627  1.558473  0.004658    1.066550
# 4                0.0930   0.0145    0.142157  1.528568  0.005014    1.057303
# ..                  ...      ...         ...       ...       ...         ...
# 231              0.1010   0.0120    0.101695  1.006880  0.000082    1.000774
# 232              0.1180   0.0110    0.118280  1.002369  0.000026    1.000317
# 233              0.0930   0.0110    0.093220  1.002369  0.000026    1.000243
# 234              0.0925   0.0105    0.092511  1.000119  0.000001    1.000012
# 235              0.1135   0.0105    0.113514  1.000119  0.000001    1.000015
#
# [236 rows x 9 columns]
